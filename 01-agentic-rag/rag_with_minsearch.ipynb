# %%
import os
import sys
from pathlib import Path

sys.path.append(str(Path.cwd().parent))

from dotenv import load_dotenv

from openai import OpenAI

from rag import RAGBase
from ingest_in_minsearch import build_index
from lib.sources import load_faq_data

# %%
load_dotenv()
# Out:
# True

# %%
openai_client = OpenAI(api_key=os.getenv("SECRET_OPENAI_API_KEY"))

# %%
documents = load_faq_data()
index = build_index(documents)

openai_client = OpenAI(api_key=os.getenv("SECRET_OPENAI_API_KEY"))

assistant = RAGBase(
    index=index,
    llm_client=openai_client,
)

answer = assistant.rag("I just discovered the course. Can I join now?")
print(answer)
# Out:
# The cost to answer this question is: $0.00043.
#
# The answer from the llm is:
#
# Yes, you can still join now. If you want a certificate, you need to submit your project while submissions are still being accepted.
