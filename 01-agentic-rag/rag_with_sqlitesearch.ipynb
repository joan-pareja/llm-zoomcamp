# %%
from dotenv import load_dotenv

from openai import OpenAI
from sqlitesearch import TextSearchIndex

from rag import RAGBase

# %%
load_dotenv()
# Out:
# True

# %%
sqlite_index = TextSearchIndex(
    text_fields=["question", "section", "answer"],
    keyword_fields=["course"],
    db_path="faq.db"
)

# %%
openai_client = OpenAI()

# %%
openai_client = OpenAI()

assistant = RAGBase(
    index=sqlite_index,
    llm_client=openai_client,
)

# %%
answer = assistant.rag("I just discovered the course. Can I join now?")
print(answer)
# Out:
# The cost to answer this question is: $0.000445.
#
# The answer from the llm is:
#
# Yes, you can still join now. If you want a certificate, make sure to submit your project while submissions are still open.

# %%
answer = assistant.rag("How do I run Olama?")
print(answer)
# Out:
# The cost to answer this question is: $0.000608.
#
# The answer from the llm is:
#
# I don't know.
